# %% [markdown]
# # First Python Program

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Output flow
# `Input` → `Code` → `Output`

# %%
print("My name is Rahul")
# Out:
# My name is Rahul

# %% [markdown]
# ## Key idea
# `print()` is used to display output on the screen.
